# %% [markdown]
# <a href="https://colab.research.google.com/github/Hannah-Russell/DTSC4050/blob/main/Week_02-Getting_the_Data/Week_02_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 02: Assignment
#
# by Hannah Russell
# ## Getting Started
#
# * Colab - get notebook from gitmystuff DTSC4050 repository
# * Save a Copy in Drive
# * Remove Copy of
# * Edit your name
# * Clean up Colab Notebooks folder
# * Submit shared link
# * Finish the assignment
#
# ## Assignment
#
# * Import three different datasets, one from sklearn.datasets, one from seaborn.load_dataset, and one from the UCI Machine Learning Repository
# * Create a dataframe for each dataset if necessary
# * Print the shape
# * Print the information about the dataset using info()
# * Show the first five rows of each dataset

# %% [markdown]
# I will be using text cells above each chunk of code to express any thoughts, reasonings, questions, etc. Please let me know if there is a different way you would like future assignments done.

# %% [markdown]
# For the code below I was stuck on how to get the head function to work, I utilized colab's AI assistance to make the data frame and then create the head command to show a clean and nice set of data. Then I reread the instructions and added the shape and info commands.

# %%
# sklearn example
import pandas as pd

from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns = iris.feature_names)
print(df.shape)
print(df.info())
df.head()
# Out:
# (150, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB
# None
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# Followed how I did the above code as well as how we coded the class 2 activity. I chose to do the diamonds dataset because it seemed nice and it's different from what we did in class.

# %%
# seaborn example
import seaborn as sb

sb.get_dataset_names()

diamonds = sb.load_dataset('diamonds')
print(diamonds.shape)
print(diamonds.info())
diamonds.head()
# Out:
# (53940, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB
# None
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# ...

# %% [markdown]
# I first went to the week 2 in class activity to find the correct website to download a repository from. Then when I selected the dataset I wanted, I utilized the 'Import in Python' button to code from the lines "from ucimlrepo impoort fetch_ucirepo" down to "print(mushroom.variable)." The rest after that, I typed out myself.

# %%
# uci machine learning repository example
# !pip install ucimlrepo
import pandas as pd

from ucimlrepo import fetch_ucirepo

# fetch dataset
mushroom = fetch_ucirepo(id=73)

# data (as pandas dataframes)
X = mushroom.data.features
y = mushroom.data.targets

# metadata
print(mushroom.metadata)

# variable information
print(mushroom.variables)

mdf = pd.read_csv(mushroom.metadata.data_url) # mdf is short for Mushroom Data Frame
print(" ") #I'm adding this space line since it makes the printed code look nicer in my opinion
print(mdf.shape)
print(mdf.info())
mdf.head()
# Out:
# ...
# {'uci_id': 73, 'name': 'Mushroom', 'repository_url': 'https://archive.ics.uci.edu/dataset/73/mushroom', 'data_url': 'https://archive.ics.uci.edu/static/public/73/data.csv', 'abstract': 'From Audobon Society Field Guide; mushrooms described in terms of physical characteristics; classification: poisonous or edible', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 8124, 'num_features': 22, 'feature_types': ['Categorical'], 'demographics': [], 'target_col': ['poisonous'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1981, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5959T', 'creators': [], 'intro_paper': None, 'additional_info': {'summary': "This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525).  Each species is identified as definitely edible, definitely 
# ...
